# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from keras import backend as K

import tensorflow as tf

# %%
# including Root Mean Square Error function, required for report

# loss function from demo code
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

# %%
# include weather data from South Alabama 
# Locate weather data path and create data set
WeatherDataPath = r"C:\Users\Peter Chapman\Personal_Research_Projects\weather-parameters-prediction-ML\LSTM Weather Code\Project 5 Mesonet Dataset.csv"
WeatherData = pd.read_csv(
    WeatherDataPath,
    parse_dates=['Hour'],
    index_col='Hour'
)

# fourth variable of interest: pressure
# using air pressure for this project
PressureData = WeatherData[['Pressure_2']]
# Out:
# C:\RTemp\ipykernel_14160\4219722132.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   WeatherData = pd.read_csv(

# %%
# Normalize the pressure data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_pressure_data = scaler.fit_transform(PressureData.values)

# Modified function to create dataset for multi-step prediction
def create_dataset(dataset, time_step=12, future_step=4): # 4 hours data from first 12 hours
    X, Y = [], []
    for i in range(len(dataset) - time_step - future_step):
        # Input: previous 'time_step' hours
        a = dataset[i:(i + time_step), 0]
        X.append(a)
        # Output: next 'future_step' hours
        b = dataset[(i + time_step):(i + time_step + future_step), 0]
        Y.append(b)
    return np.array(X), np.array(Y)

# Create dataset with 12 input hours and 4 output hours
X, y = create_dataset(scaled_pressure_data, time_step=12, future_step=4)

# Split into train and test by 80/20 ratio, as discussed in class
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0, shuffle=False # want shuffle off, because time-series data
)

# Reshape for LSTM [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# printing shapes of training data and testing data
print(f"Training data shape: X_train={X_train.shape}, y_train={y_train.shape}")
print(f"Testing data shape: X_test={X_test.shape}, y_test={y_test.shape}")
# Out:
# Training data shape: X_train=(10355, 12, 1), y_train=(10355, 4)
# Testing data shape: X_test=(2589, 12, 1), y_test=(2589, 4)

# %%
# Build the LSTM model
model = Sequential()

# First LSTM layer with 50 units, returns sequences for stacking
model.add(LSTM(50, return_sequences=True, input_shape=(12, 1)))

# TODO: Add two additional LSTM layers
# Second LSTM layer with 50 units, returns sequences
model.add(LSTM(50, return_sequences=True))

# Third LSTM layer with 50 units, returns sequences
model.add(LSTM(50, return_sequences=True))

# Fourth LSTM layer with 50 units, does not return sequences
model.add(LSTM(50, return_sequences=False))

# TODO: Add Dropout layers
# Dropout layer to prevent overfitting (20% dropout rate)
model.add(Dropout(0.2))

# TODO: Add Dense layer with ReLU as activation function
# Dense layer with 25 neurons and ReLU activation
model.add(Dense(25, activation='relu'))

# Additional Dense layer with 25 neurons
model.add(Dense(25))

# Output layer with 4 neurons (predicting 4 future hours)
model.add(Dense(4))

# Compile the model
# TODO: Change to two different optimizers other than Adam
# Using RMSprop optimizer as alternative to Adam
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.0001)

model.compile(
    optimizer=optimizer,
    loss='mean_squared_error',
    metrics=['mean_absolute_error', 'mean_squared_error', rmse]
)

# Display model architecture
model.summary()
# Out:
# c:\Users\Peter Chapman\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_12 (LSTM)                  │ (None, 12, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_13 (LSTM)                  │ (None, 12, 50)         │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_14 (LSTM)                  │ (None, 12, 50)         │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_15 (LSTM)                  │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 25)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 4)              │           104 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,029 (285.27 KB)
#  Trainable params: 73,029 (285.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
num_epochs = 45
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=num_epochs,
    batch_size=32,
    verbose=1
)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform to get actual pressure values
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train_actual = scaler.inverse_transform(y_train)
y_test_actual = scaler.inverse_transform(y_test)

# Calculate Mean Square Error for training and testing
train_mse = np.mean((y_train_actual - train_predict) ** 2)
test_mse = np.mean((y_test_actual - test_predict) ** 2)


# printing training and testing errors
print(f"\n===== Pressure Model Results =====")
print(f"Training MSE: {train_mse:.4f}")
print(f"Testing MSE: {test_mse:.4f}")
print(f"Training RMSE: {np.sqrt(train_mse):.4f}")
print(f"Testing RMSE: {np.sqrt(test_mse):.4f}")
# Out:
# Epoch 1/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 19ms/step - loss: 6.9365e-04 - mean_absolute_error: 0.0192 - mean_squared_error: 6.9365e-04 - rmse: 0.0243 - val_loss: 3.3732e-04 - val_mean_absolute_error: 0.0150 - val_mean_squared_error: 3.3732e-04 - val_rmse: 0.0155
# Epoch 2/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 4.9717e-04 - mean_absolute_error: 0.0163 - mean_squared_error: 4.9717e-04 - rmse: 0.0209 - val_loss: 3.4171e-04 - val_mean_absolute_error: 0.0155 - val_mean_squared_error: 3.4171e-04 - val_rmse: 0.0159
# Epoch 3/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - loss: 4.9056e-04 - mean_absolute_error: 0.0162 - mean_squared_error: 4.9056e-04 - rmse: 0.0208 - val_loss: 3.1950e-04 - val_mean_absolute_error: 0.0141 - val_mean_squared_error: 3.1950e-04 - val_rmse: 0.0146
# Epoch 4/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 4.8519e-04 - mean_absolute_error: 0.0161 - mean_squared_error: 4.8519e-04 - rmse: 0.0206 - val_loss: 3.3681e-04 - val_mean_absolute_error: 0.0154 - val_mean_squared_error: 3.3681e-04 - val_rmse: 0.0159
# Epoch 5/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 4.7965e-04 - mean_absolute_error: 0.0159 - mean_squared_error: 4.7965e-04 - rmse: 0.0205 - val_loss: 3.2250e-04 - val_mean_absolute_error: 0.0147 - val_mean_squared_error: 3.2250e-04 - val_rmse: 0.0152
# Epoch 6/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 4.7583e-04 - mean_absolute_error: 0.0159 - mean_squared_error: 4.7583e-04 - rmse: 0.0204 - val_loss: 3.2065e-04 - val_mean_absolute_error: 0.0147 - val_mean_squared_error: 3.2065e-04 - val_rmse: 0.0152
# Epoch 7/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 4.6939e-04 - mean_absolute_error: 0.0157 - mean_squared_error: 4.6939e-04 - rmse: 0.0203 - val_loss: 3.3028e-04 - val_mean_absolute_error: 0.0151 - val_mean_squared_error: 3.3028e-04 - val_rmse: 0.0159
# Epoch 8/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 4.6204e-04 - mean_absolute_error: 0.0156 - mean_squared_error: 4.6204e-04 - rmse: 0.0201 - val_loss: 2.8908e-04 - val_mean_absolute_error: 0.0125 - val_mean_squared_error: 2.8908e-04 - val_rmse: 0.0131
# Epoch 9/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 4.5469e-04 - mean_absolute_error: 0.0154 - mean_squared_error: 4.5469e-04 - rmse: 0.0199 - val_loss: 2.8546e-04 - val_mean_absolute_error: 0.0128 - val_mean_squared_error: 2.8546e-04 - val_rmse: 0.0134
# Epoch 10/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 4.4575e-04 - mean_absolute_error: 0.0152 - mean_squared_error: 4.4575e-04 - rmse: 0.0197 - val_loss: 3.0745e-04 - val_mean_absolute_error: 0.0147 - val_mean_squared_error: 3.0745e-04 - val_rmse: 0.0153
# Epoch 11/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 4.3556e-04 - mean_absolute_error: 0.0150 - mean_squared_error: 4.3556e-04 - rmse: 0.0194 - val_loss: 2.9383e-04 - val_mean_absolute_error: 0.0144 - val_mean_squared_error: 2.9383e-04 - val_rmse: 0.0149
# Epoch 12/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 4.2226e-04 - mean_absolute_error: 0.0147 - mean_squared_error: 4.2226e-04 - rmse: 0.0190 - val_loss: 2.5763e-04 - val_mean_absolute_error: 0.0119 - val_mean_squared_error: 2.5763e-04 - val_rmse: 0.0126
# Epoch 13/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 4.0771e-04 - mean_absolute_error: 0.0144 - mean_squared_error: 4.0771e-04 - rmse: 0.0186 - val_loss: 2.6879e-04 - val_mean_absolute_error: 0.0137 - val_mean_squared_error: 2.6879e-04 - val_rmse: 0.0142
# Epoch 14/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 3.9056e-04 - mean_absolute_error: 0.0140 - mean_squared_error: 3.9056e-04 - rmse: 0.0182 - val_loss: 2.4276e-04 - val_mean_absolute_error: 0.0126 - val_mean_squared_error: 2.4276e-04 - val_rmse: 0.0132
# Epoch 15/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 11s 34ms/step - loss: 3.6964e-04 - mean_absolute_error: 0.0134 - mean_squared_error: 3.6964e-04 - rmse: 0.0176 - val_loss: 2.1775e-04 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 2.1775e-04 - val_rmse: 0.0121
# Epoch 16/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 3.4476e-04 - mean_absolute_error: 0.0128 - mean_squared_error: 3.4476e-04 - rmse: 0.0168 - val_loss: 1.9494e-04 - val_mean_absolute_error: 0.0104 - val_mean_squared_error: 1.9494e-04 - val_rmse: 0.0112
# Epoch 17/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 3.1771e-04 - mean_absolute_error: 0.0120 - mean_squared_error: 3.1771e-04 - rmse: 0.0160 - val_loss: 1.7706e-04 - val_mean_absolute_error: 0.0104 - val_mean_squared_error: 1.7706e-04 - val_rmse: 0.0111
# Epoch 18/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 2.8842e-04 - mean_absolute_error: 0.0111 - mean_squared_error: 2.8842e-04 - rmse: 0.0149 - val_loss: 1.5875e-04 - val_mean_absolute_error: 0.0099 - val_mean_squared_error: 1.5875e-04 - val_rmse: 0.0108
# Epoch 19/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 2.5892e-04 - mean_absolute_error: 0.0101 - mean_squared_error: 2.5892e-04 - rmse: 0.0139 - val_loss: 1.3547e-04 - val_mean_absolute_error: 0.0091 - val_mean_squared_error: 1.3547e-04 - val_rmse: 0.0100
# Epoch 20/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 9s 28ms/step - loss: 2.3372e-04 - mean_absolute_error: 0.0092 - mean_squared_error: 2.3372e-04 - rmse: 0.0129 - val_loss: 1.0617e-04 - val_mean_absolute_error: 0.0065 - val_mean_squared_error: 1.0617e-04 - val_rmse: 0.0077
# Epoch 21/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 2.1112e-04 - mean_absolute_error: 0.0084 - mean_squared_error: 2.1112e-04 - rmse: 0.0119 - val_loss: 1.2230e-04 - val_mean_absolute_error: 0.0094 - val_mean_squared_error: 1.2230e-04 - val_rmse: 0.0101
# Epoch 22/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.9249e-04 - mean_absolute_error: 0.0076 - mean_squared_error: 1.9249e-04 - rmse: 0.0110 - val_loss: 7.7269e-05 - val_mean_absolute_error: 0.0058 - val_mean_squared_error: 7.7269e-05 - val_rmse: 0.0068
# Epoch 23/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.7921e-04 - mean_absolute_error: 0.0070 - mean_squared_error: 1.7921e-04 - rmse: 0.0103 - val_loss: 7.7644e-05 - val_mean_absolute_error: 0.0062 - val_mean_squared_error: 7.7644e-05 - val_rmse: 0.0073
# Epoch 24/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 1.7180e-04 - mean_absolute_error: 0.0066 - mean_squared_error: 1.7180e-04 - rmse: 0.0098 - val_loss: 6.4231e-05 - val_mean_absolute_error: 0.0051 - val_mean_squared_error: 6.4231e-05 - val_rmse: 0.0059
# Epoch 25/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 1.6622e-04 - mean_absolute_error: 0.0063 - mean_squared_error: 1.6622e-04 - rmse: 0.0095 - val_loss: 9.0959e-05 - val_mean_absolute_error: 0.0077 - val_mean_squared_error: 9.0959e-05 - val_rmse: 0.0083
# Epoch 26/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 1.6310e-04 - mean_absolute_error: 0.0061 - mean_squared_error: 1.6310e-04 - rmse: 0.0093 - val_loss: 6.2988e-05 - val_mean_absolute_error: 0.0052 - val_mean_squared_error: 6.2988e-05 - val_rmse: 0.0059
# Epoch 27/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.5932e-04 - mean_absolute_error: 0.0059 - mean_squared_error: 1.5932e-04 - rmse: 0.0091 - val_loss: 7.1790e-05 - val_mean_absolute_error: 0.0055 - val_mean_squared_error: 7.1790e-05 - val_rmse: 0.0065
# Epoch 28/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.5852e-04 - mean_absolute_error: 0.0058 - mean_squared_error: 1.5852e-04 - rmse: 0.0090 - val_loss: 5.2778e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 5.2778e-05 - val_rmse: 0.0043
# Epoch 29/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 1.5969e-04 - mean_absolute_error: 0.0058 - mean_squared_error: 1.5969e-04 - rmse: 0.0090 - val_loss: 5.2216e-05 - val_mean_absolute_error: 0.0034 - val_mean_squared_error: 5.2216e-05 - val_rmse: 0.0042
# Epoch 30/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 1.5717e-04 - mean_absolute_error: 0.0056 - mean_squared_error: 1.5717e-04 - rmse: 0.0089 - val_loss: 5.1473e-05 - val_mean_absolute_error: 0.0034 - val_mean_squared_error: 5.1473e-05 - val_rmse: 0.0041
# Epoch 31/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 12s 36ms/step - loss: 1.5603e-04 - mean_absolute_error: 0.0057 - mean_squared_error: 1.5603e-04 - rmse: 0.0089 - val_loss: 5.6852e-05 - val_mean_absolute_error: 0.0043 - val_mean_squared_error: 5.6852e-05 - val_rmse: 0.0052
# Epoch 32/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.5380e-04 - mean_absolute_error: 0.0056 - mean_squared_error: 1.5380e-04 - rmse: 0.0088 - val_loss: 5.1473e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 5.1473e-05 - val_rmse: 0.0041
# Epoch 33/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 9s 29ms/step - loss: 1.5494e-04 - mean_absolute_error: 0.0056 - mean_squared_error: 1.5494e-04 - rmse: 0.0088 - val_loss: 5.6284e-05 - val_mean_absolute_error: 0.0044 - val_mean_squared_error: 5.6284e-05 - val_rmse: 0.0051
# Epoch 34/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 29ms/step - loss: 1.5612e-04 - mean_absolute_error: 0.0056 - mean_squared_error: 1.5612e-04 - rmse: 0.0088 - val_loss: 5.0756e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 5.0756e-05 - val_rmse: 0.0040
# Epoch 35/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 1.5443e-04 - mean_absolute_error: 0.0056 - mean_squared_error: 1.5443e-04 - rmse: 0.0087 - val_loss: 5.3711e-05 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 5.3711e-05 - val_rmse: 0.0047
# Epoch 36/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.5296e-04 - mean_absolute_error: 0.0056 - mean_squared_error: 1.5296e-04 - rmse: 0.0087 - val_loss: 5.1674e-05 - val_mean_absolute_error: 0.0036 - val_mean_squared_error: 5.1674e-05 - val_rmse: 0.0043
# Epoch 37/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 9s 27ms/step - loss: 1.5517e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.5517e-04 - rmse: 0.0088 - val_loss: 6.8368e-05 - val_mean_absolute_error: 0.0057 - val_mean_squared_error: 6.8368e-05 - val_rmse: 0.0065
# Epoch 38/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.5420e-04 - mean_absolute_error: 0.0056 - mean_squared_error: 1.5420e-04 - rmse: 0.0088 - val_loss: 5.0769e-05 - val_mean_absolute_error: 0.0033 - val_mean_squared_error: 5.0769e-05 - val_rmse: 0.0041
# Epoch 39/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.5306e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.5306e-04 - rmse: 0.0088 - val_loss: 5.3638e-05 - val_mean_absolute_error: 0.0040 - val_mean_squared_error: 5.3638e-05 - val_rmse: 0.0047
# Epoch 40/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.5553e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.5553e-04 - rmse: 0.0087 - val_loss: 5.1157e-05 - val_mean_absolute_error: 0.0035 - val_mean_squared_error: 5.1157e-05 - val_rmse: 0.0042
# Epoch 41/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.5504e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.5504e-04 - rmse: 0.0088 - val_loss: 5.0419e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 5.0419e-05 - val_rmse: 0.0040
# Epoch 42/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 30ms/step - loss: 1.5303e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.5303e-04 - rmse: 0.0087 - val_loss: 6.8809e-05 - val_mean_absolute_error: 0.0056 - val_mean_squared_error: 6.8809e-05 - val_rmse: 0.0063
# Epoch 43/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 1.5459e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.5459e-04 - rmse: 0.0088 - val_loss: 1.7941e-04 - val_mean_absolute_error: 0.0120 - val_mean_squared_error: 1.7941e-04 - val_rmse: 0.0127
# Epoch 44/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 11s 32ms/step - loss: 1.5443e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.5443e-04 - rmse: 0.0088 - val_loss: 1.1351e-04 - val_mean_absolute_error: 0.0089 - val_mean_squared_error: 1.1351e-04 - val_rmse: 0.0096
# Epoch 45/45
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 1.5434e-04 - mean_absolute_error: 0.0055 - mean_squared_error: 1.5434e-04 - rmse: 0.0087 - val_loss: 5.0719e-05 - val_mean_absolute_error: 0.0032 - val_mean_squared_error: 5.0719e-05 - val_rmse: 0.0040
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 6s 16ms/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step
#
# ===== Pressure Model Results =====
# Training MSE: 4.7683
# Testing MSE: 1.6861
# Training RMSE: 2.1836
# Testing RMSE: 1.2985

# %%
# Plotting model losses and predictions

# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['rmse'], label='Training RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Model RMSE Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# Plot sample predictions vs actual (first 100 test samples)
plt.figure(figsize=(15, 8))
num_samples = min(100, len(test_predict))

for hour in range(4):
    plt.subplot(2, 2, hour + 1)
    plt.plot(y_test_actual[:num_samples, hour], label='Actual', marker='o', markersize=3)
    plt.plot(test_predict[:num_samples, hour], label='Predicted', marker='x', markersize=3)
    plt.title(f'Hour +{hour+1} Prediction vs Actual')
    plt.xlabel('Sample Index')
    plt.ylabel('Air Pressure at 2 Meters in mmHg')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()
