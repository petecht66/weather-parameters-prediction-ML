# %%
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# from tensorflow import keras
from keras.models import Sequential
from keras.layers import LSTM, Dense, Dropout
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
# from keras import backend as K

import tensorflow as tf

# %%
# including Root Mean Square Error function, required for report

# loss function from demo code
def rmse(y_true, y_pred):
    return tf.sqrt(tf.reduce_mean(tf.square(y_pred - y_true)))

# %%
# include weather data from South Alabama 
# Locate weather data path and create data set
WeatherDataPath = r"C:\Users\Peter Chapman\Personal_Research_Projects\weather-parameters-prediction-ML\LSTM Weather Code\Project 5 Mesonet Dataset.csv"
WeatherData = pd.read_csv(
    WeatherDataPath,
    parse_dates=['Hour'],
    index_col='Hour'
)

# first variable of interest: temperature
# air temperature at 2 meters in degrees Celsius
TemperatureData = WeatherData[['AirT_2m']]
# Out:
# C:\RTemp\ipykernel_28836\156590218.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   WeatherData = pd.read_csv(

# %%
# Normalize the temperature data
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_temp_data = scaler.fit_transform(TemperatureData.values)

# Modified function to create dataset for multi-step prediction
def create_dataset(dataset, time_step=12, future_step=4): # 4 hours data from first 12 hours
    X, Y = [], []
    for i in range(len(dataset) - time_step - future_step):
        # Input: previous 'time_step' hours
        a = dataset[i:(i + time_step), 0]
        X.append(a)
        # Output: next 'future_step' hours
        b = dataset[(i + time_step):(i + time_step + future_step), 0]
        Y.append(b)
    return np.array(X), np.array(Y)

# Create dataset with 12 input hours and 4 output hours
X, y = create_dataset(scaled_temp_data, time_step=12, future_step=4)

# Split into train and test by 80/20 ratio, as discussed in class
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0, shuffle=False # want shuffle off, because time-series data
)

# Reshape for LSTM [samples, time steps, features]
X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# printing shapes of training data and testing data
print(f"Training data shape: X_train={X_train.shape}, y_train={y_train.shape}")
print(f"Testing data shape: X_test={X_test.shape}, y_test={y_test.shape}")
# Out:
# Training data shape: X_train=(10355, 12, 1), y_train=(10355, 4)
# Testing data shape: X_test=(2589, 12, 1), y_test=(2589, 4)

# %%
# Build the LSTM model
model = Sequential()

# First LSTM layer with 50 units, returns sequences for stacking
model.add(LSTM(50, return_sequences=True, input_shape=(12, 1)))

# TODO: Add two additional LSTM layers
# Second LSTM layer with 50 units, returns sequences
model.add(LSTM(50, return_sequences=True))

# Third LSTM layer with 50 units, returns sequences
model.add(LSTM(50, return_sequences=True))

# Fourth LSTM layer with 50 units, does not return sequences
model.add(LSTM(50, return_sequences=False))

# TODO: Add Dropout layers
# Dropout layer to prevent overfitting (20% dropout rate)
model.add(Dropout(0.2))

# TODO: Add Dense layer with ReLU as activation function
# Dense layer with 25 neurons and ReLU activation
model.add(Dense(25, activation='relu'))

# Additional Dense layer with 25 neurons
model.add(Dense(25))

# Output layer with 4 neurons (predicting 4 future hours)
model.add(Dense(4))

# Compile the model
# TODO: Change to two different optimizers other than Adam
# Using RMSprop optimizer as alternative to Adam
optimizer = tf.keras.optimizers.RMSprop(learning_rate=0.001)

model.compile(
    optimizer=optimizer,
    loss='mean_squared_error',
    metrics=['mean_absolute_error', 'mean_squared_error', rmse]
)

# Display model architecture
model.summary()
# Out:
# c:\Users\Peter Chapman\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_4 (LSTM)                   │ (None, 12, 50)         │        10,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_5 (LSTM)                   │ (None, 12, 50)         │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_6 (LSTM)                   │ (None, 12, 50)         │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 50)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 25)             │           650 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 4)              │           104 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 73,029 (285.27 KB)
#  Trainable params: 73,029 (285.27 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train the model
num_epochs = 30
history = model.fit(
    X_train,
    y_train,
    validation_data=(X_test, y_test),
    epochs=num_epochs,
    batch_size=32,
    verbose=1
)

# Make predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform to get actual temperature values
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)
y_train_actual = scaler.inverse_transform(y_train)
y_test_actual = scaler.inverse_transform(y_test)

# Calculate Mean Square Error for training and testing
train_mse = np.mean((y_train_actual - train_predict) ** 2)
test_mse = np.mean((y_test_actual - test_predict) ** 2)


# printing training and testing errors
print(f"\n===== Temperature Model Results =====")
print(f"Training MSE: {train_mse:.4f}")
print(f"Testing MSE: {test_mse:.4f}")
print(f"Training RMSE: {np.sqrt(train_mse):.4f}")
print(f"Testing RMSE: {np.sqrt(test_mse):.4f}")
# Out:
# Epoch 1/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 7s 22ms/step - loss: 0.0010 - mean_absolute_error: 0.0231 - mean_squared_error: 0.0010 - rmse: 0.0313 - val_loss: 6.2596e-04 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 6.2596e-04 - val_rmse: 0.0196
# Epoch 2/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - loss: 0.0010 - mean_absolute_error: 0.0228 - mean_squared_error: 0.0010 - rmse: 0.0312 - val_loss: 5.5667e-04 - val_mean_absolute_error: 0.0174 - val_mean_squared_error: 5.5667e-04 - val_rmse: 0.0199
# Epoch 3/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 19s 58ms/step - loss: 9.6797e-04 - mean_absolute_error: 0.0222 - mean_squared_error: 9.6797e-04 - rmse: 0.0303 - val_loss: 5.6871e-04 - val_mean_absolute_error: 0.0187 - val_mean_squared_error: 5.6871e-04 - val_rmse: 0.0210
# Epoch 4/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 19s 58ms/step - loss: 9.0042e-04 - mean_absolute_error: 0.0218 - mean_squared_error: 9.0042e-04 - rmse: 0.0292 - val_loss: 6.7972e-04 - val_mean_absolute_error: 0.0220 - val_mean_squared_error: 6.7972e-04 - val_rmse: 0.0241
# Epoch 5/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - loss: 8.9265e-04 - mean_absolute_error: 0.0215 - mean_squared_error: 8.9265e-04 - rmse: 0.0291 - val_loss: 0.0017 - val_mean_absolute_error: 0.0354 - val_mean_squared_error: 0.0017 - val_rmse: 0.0375
# Epoch 6/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 18s 56ms/step - loss: 8.6373e-04 - mean_absolute_error: 0.0211 - mean_squared_error: 8.6373e-04 - rmse: 0.0286 - val_loss: 0.0017 - val_mean_absolute_error: 0.0309 - val_mean_squared_error: 0.0017 - val_rmse: 0.0328
# Epoch 7/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 19s 60ms/step - loss: 8.4185e-04 - mean_absolute_error: 0.0208 - mean_squared_error: 8.4185e-04 - rmse: 0.0281 - val_loss: 9.7355e-04 - val_mean_absolute_error: 0.0231 - val_mean_squared_error: 9.7355e-04 - val_rmse: 0.0254
# Epoch 8/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 20s 61ms/step - loss: 8.0155e-04 - mean_absolute_error: 0.0205 - mean_squared_error: 8.0155e-04 - rmse: 0.0275 - val_loss: 4.5279e-04 - val_mean_absolute_error: 0.0172 - val_mean_squared_error: 4.5279e-04 - val_rmse: 0.0194
# Epoch 9/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - loss: 7.6903e-04 - mean_absolute_error: 0.0200 - mean_squared_error: 7.6903e-04 - rmse: 0.0269 - val_loss: 6.4469e-04 - val_mean_absolute_error: 0.0208 - val_mean_squared_error: 6.4469e-04 - val_rmse: 0.0231
# Epoch 10/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 18s 54ms/step - loss: 7.6460e-04 - mean_absolute_error: 0.0198 - mean_squared_error: 7.6460e-04 - rmse: 0.0269 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0013 - val_rmse: 0.0300
# Epoch 11/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 18s 55ms/step - loss: 7.3664e-04 - mean_absolute_error: 0.0197 - mean_squared_error: 7.3664e-04 - rmse: 0.0264 - val_loss: 5.6731e-04 - val_mean_absolute_error: 0.0202 - val_mean_squared_error: 5.6731e-04 - val_rmse: 0.0224
# Epoch 12/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 18s 56ms/step - loss: 7.3000e-04 - mean_absolute_error: 0.0194 - mean_squared_error: 7.3000e-04 - rmse: 0.0261 - val_loss: 2.8235e-04 - val_mean_absolute_error: 0.0114 - val_mean_squared_error: 2.8235e-04 - val_rmse: 0.0138
# Epoch 13/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 19s 58ms/step - loss: 6.8813e-04 - mean_absolute_error: 0.0190 - mean_squared_error: 6.8813e-04 - rmse: 0.0254 - val_loss: 0.0010 - val_mean_absolute_error: 0.0290 - val_mean_squared_error: 0.0010 - val_rmse: 0.0310
# Epoch 14/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 11s 35ms/step - loss: 6.7786e-04 - mean_absolute_error: 0.0188 - mean_squared_error: 6.7786e-04 - rmse: 0.0253 - val_loss: 2.7298e-04 - val_mean_absolute_error: 0.0113 - val_mean_squared_error: 2.7298e-04 - val_rmse: 0.0137
# Epoch 15/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 10s 32ms/step - loss: 6.6423e-04 - mean_absolute_error: 0.0186 - mean_squared_error: 6.6423e-04 - rmse: 0.0250 - val_loss: 2.7217e-04 - val_mean_absolute_error: 0.0110 - val_mean_squared_error: 2.7217e-04 - val_rmse: 0.0134
# Epoch 16/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 21s 64ms/step - loss: 6.6109e-04 - mean_absolute_error: 0.0186 - mean_squared_error: 6.6109e-04 - rmse: 0.0250 - val_loss: 4.6369e-04 - val_mean_absolute_error: 0.0184 - val_mean_squared_error: 4.6369e-04 - val_rmse: 0.0206
# Epoch 17/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 19s 57ms/step - loss: 6.4482e-04 - mean_absolute_error: 0.0183 - mean_squared_error: 6.4482e-04 - rmse: 0.0247 - val_loss: 2.5894e-04 - val_mean_absolute_error: 0.0107 - val_mean_squared_error: 2.5894e-04 - val_rmse: 0.0131
# Epoch 18/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - loss: 6.2653e-04 - mean_absolute_error: 0.0180 - mean_squared_error: 6.2653e-04 - rmse: 0.0243 - val_loss: 3.2252e-04 - val_mean_absolute_error: 0.0135 - val_mean_squared_error: 3.2252e-04 - val_rmse: 0.0159
# Epoch 19/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 18s 55ms/step - loss: 6.2882e-04 - mean_absolute_error: 0.0180 - mean_squared_error: 6.2882e-04 - rmse: 0.0243 - val_loss: 2.8948e-04 - val_mean_absolute_error: 0.0115 - val_mean_squared_error: 2.8948e-04 - val_rmse: 0.0139
# Epoch 20/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 19s 58ms/step - loss: 6.0686e-04 - mean_absolute_error: 0.0178 - mean_squared_error: 6.0686e-04 - rmse: 0.0240 - val_loss: 2.5727e-04 - val_mean_absolute_error: 0.0109 - val_mean_squared_error: 2.5727e-04 - val_rmse: 0.0133
# Epoch 21/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 17s 52ms/step - loss: 5.9968e-04 - mean_absolute_error: 0.0177 - mean_squared_error: 5.9968e-04 - rmse: 0.0238 - val_loss: 6.9206e-04 - val_mean_absolute_error: 0.0230 - val_mean_squared_error: 6.9206e-04 - val_rmse: 0.0252
# Epoch 22/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 18s 54ms/step - loss: 5.6081e-04 - mean_absolute_error: 0.0173 - mean_squared_error: 5.6081e-04 - rmse: 0.0231 - val_loss: 3.0127e-04 - val_mean_absolute_error: 0.0126 - val_mean_squared_error: 3.0127e-04 - val_rmse: 0.0150
# Epoch 23/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - loss: 5.8485e-04 - mean_absolute_error: 0.0175 - mean_squared_error: 5.8485e-04 - rmse: 0.0235 - val_loss: 5.0952e-04 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 5.0952e-04 - val_rmse: 0.0192
# Epoch 24/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 17s 53ms/step - loss: 5.7001e-04 - mean_absolute_error: 0.0172 - mean_squared_error: 5.7001e-04 - rmse: 0.0233 - val_loss: 5.5276e-04 - val_mean_absolute_error: 0.0169 - val_mean_squared_error: 5.5276e-04 - val_rmse: 0.0191
# Epoch 25/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 19s 48ms/step - loss: 5.8276e-04 - mean_absolute_error: 0.0176 - mean_squared_error: 5.8276e-04 - rmse: 0.0235 - val_loss: 3.4521e-04 - val_mean_absolute_error: 0.0122 - val_mean_squared_error: 3.4521e-04 - val_rmse: 0.0145
# Epoch 26/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 17s 52ms/step - loss: 5.5990e-04 - mean_absolute_error: 0.0170 - mean_squared_error: 5.5990e-04 - rmse: 0.0229 - val_loss: 2.9131e-04 - val_mean_absolute_error: 0.0116 - val_mean_squared_error: 2.9131e-04 - val_rmse: 0.0142
# Epoch 27/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 18s 56ms/step - loss: 5.3502e-04 - mean_absolute_error: 0.0168 - mean_squared_error: 5.3502e-04 - rmse: 0.0225 - val_loss: 3.4833e-04 - val_mean_absolute_error: 0.0150 - val_mean_squared_error: 3.4833e-04 - val_rmse: 0.0173
# Epoch 28/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 19s 57ms/step - loss: 5.3803e-04 - mean_absolute_error: 0.0168 - mean_squared_error: 5.3803e-04 - rmse: 0.0225 - val_loss: 9.6592e-04 - val_mean_absolute_error: 0.0269 - val_mean_squared_error: 9.6592e-04 - val_rmse: 0.0290
# Epoch 29/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 20s 62ms/step - loss: 5.3752e-04 - mean_absolute_error: 0.0169 - mean_squared_error: 5.3752e-04 - rmse: 0.0226 - val_loss: 2.2576e-04 - val_mean_absolute_error: 0.0104 - val_mean_squared_error: 2.2576e-04 - val_rmse: 0.0127
# Epoch 30/30
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 17s 54ms/step - loss: 5.3194e-04 - mean_absolute_error: 0.0168 - mean_squared_error: 5.3194e-04 - rmse: 0.0225 - val_loss: 2.0702e-04 - val_mean_absolute_error: 0.0096 - val_mean_squared_error: 2.0702e-04 - val_rmse: 0.0117
# 324/324 ━━━━━━━━━━━━━━━━━━━━ 7s 20ms/step
# 81/81 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step
#
# ===== Temperature Model Results =====
# Training MSE: 0.0338
# Testing MSE: 0.0325
# Training RMSE: 0.1839
# Testing RMSE: 0.1803

# %%
# Plotting model losses and predictions

# Plot training history
plt.figure(figsize=(12, 4))

plt.subplot(1, 2, 1)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Model Loss Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss (MSE)')
plt.legend()
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(history.history['rmse'], label='Training RMSE')
plt.plot(history.history['val_rmse'], label='Validation RMSE')
plt.title('Model RMSE Over Epochs')
plt.xlabel('Epoch')
plt.ylabel('RMSE')
plt.legend()
plt.grid(True)

plt.tight_layout()
plt.show()

# Plot sample predictions vs actual (first 100 test samples)
plt.figure(figsize=(15, 8))
num_samples = min(100, len(test_predict))

for hour in range(4):
    plt.subplot(2, 2, hour + 1)
    plt.plot(y_test_actual[:num_samples, hour], label='Actual', marker='o', markersize=3)
    plt.plot(test_predict[:num_samples, hour], label='Predicted', marker='x', markersize=3)
    plt.title(f'Hour +{hour+1} Prediction vs Actual')
    plt.xlabel('Sample Index')
    plt.ylabel('Air Temperature at 2 Meters (°C)')
    plt.legend()
    plt.grid(True)

plt.tight_layout()
plt.show()
